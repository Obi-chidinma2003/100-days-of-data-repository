# %% [markdown]
# <a href="https://colab.research.google.com/github/Obi-chidinma2003/100-days-of-data-repository/blob/main/Day_08_phyton_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello phyton! Starting my data journey")
# Out:
# Hello phyton! Starting my data journey

# %% [markdown]
# Phyton does not use arrays,it makes use of lists.

# %% [markdown]
# # LIST USING PYTON

# %% [markdown]
# #SYNTAX FOR INSERTING CELL
# **ctrl+m+b
# #SYNTAX FOR DELETING CELL
# **ctrl+m+d
# #Syntax for bringing back what was deleted
# **ctrl+m+z
# #syntax for single line comments
# ** #
# #syntax for double line comments
# """

# %%
names = [ "kola", "bella", "Bola"]
names
# Out:
# ['kola', 'bella', 'Bola']

# %% [markdown]
# #lists can contain different values or entities.

# %%
manuella =[""]
