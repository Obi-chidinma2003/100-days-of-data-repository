# %% [markdown]
# <a href="https://colab.research.google.com/github/Obi-chidinma2003/100-days-of-data-repository/blob/main/Day_10_selecting_rows_columns_(data_filtering).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# VIEWING THE CONTENT OF THE DATASET.

# %%
path="/content/drive/MyDrive/Dataset/dairy_dataset.csv"
df=pd.read_csv(path)
df.head(10)
# Out:
#         Location  Total Land Area (Acres)  Number Of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
# 5      Telangana                    87.64              51    Medium
# 6      Karnataka                    73.28              74     Small
# 7          Bihar                    67.61              77    Medium
# 8    West Bengal                    72.31              76    Medium
# 9      Telangana                   413.24              36     Large
#
#         Date  Product Id Product Name                 Brand  \
# 0  44,609.00           5    Ice Cream           Dodla Dairy
# 1      44531           1         Milk                  Amul
# ...

# %% [markdown]
# **SELECTING BRAND COLUMN**

# %%
df["Brand"]
# Out:
# 0                Dodla Dairy
# 1                       Amul
# 2                Dodla Dairy
# 3       Britannia Industries
# 4               Mother Dairy
#                 ...
# 4320            Mother Dairy
# 4321            Palle2Patnam
# 4322            Mother Dairy
# 4323                     Raj
# 4324            Mother Dairy
# Name: Brand, Length: 4325, dtype: object

# %% [markdown]
# SELECTING MULTIPLE COLUMNS

# %%
df[["Location", "Product Name", "Brand"]]
# Out:
#            Location Product Name                 Brand
# 0         Telangana    Ice Cream           Dodla Dairy
# 1     Uttar Pradesh         Milk                  Amul
# 2        Tamil Nadu       Yogurt           Dodla Dairy
# 3         Telangana       Cheese  Britannia Industries
# 4       Maharashtra   Buttermilk          Mother Dairy
# ...             ...          ...                   ...
# 4320          Delhi         Curd          Mother Dairy
# 4321      Jharkhand       Yogurt          Palle2Patnam
# 4322     Chandigarh         Curd          Mother Dairy
# 4323    Maharashtra         Curd                   Raj
# 4324      Rajasthan         Milk          Mother Dairy
#
# [4325 rows x 3 columns]

# %% [markdown]
# SELECTING THEFIRST ROW[0]

# %%
df.iloc[0]
# Out:
# Location                                    Telangana
# Total Land Area (Acres)                        310.84
# Number Of Cows                                     96
# Farm Size                                      Medium
# Date                                        44,609.00
# Product Id                                          5
# Product Name                                Ice Cream
# Brand                                     Dodla Dairy
# Quantity (Liters/Kg)                            222.4
# Price Per Unit                                  85.72
# Total Value                                 19064.128
# Shelf Life (Days)                                  25
# Storage Condition                              Frozen
# Production Date                                 44557
# Expiration Date                                 44582
# Quantity Sold (Liters/Kg)                           7
# Price Per Unit (Sold)                           82.24
# ...

# %% [markdown]
# SELECTING THE 20TH ROWS

# %%
df.iloc[20]
# Out:
# Location                                  Jharkhand
# Total Land Area (Acres)                      705.01
# Number Of Cows                                   24
# Farm Size                                     Large
# Date                                          43970
# Product Id                                        9
# Product Name                                 Paneer
# Brand                                           Raj
# Quantity (Liters/Kg)                          88.69
# Price Per Unit                                87.53
# Total Value                               7763.0357
# Shelf Life (Days)                                10
# Storage Condition                      Refrigerated
# Production Date                               43925
# Expiration Date                               43935
# Quantity Sold (Liters/Kg)                        26
# Price Per Unit (Sold)                          87.3
# Approx. Total Revenue(Inr)                   2269.8
# ...

# %% [markdown]
# SELECTING MULTIPLE ROWS

# %%
df.loc[3,"Brand"]
# Out:
# 'Britannia Industries'
