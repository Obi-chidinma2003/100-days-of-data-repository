# %% [markdown]
# <a href="https://colab.research.google.com/github/Obi-chidinma2003/100-days-of-data-repository/blob/main/Day_11_Intro_to_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import numpy as np
import time

# %% [markdown]
# **BASIC NUMPY ARRAYS**

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
a =np.array([1,2,3,4])

# %%
b=np.array([0,-5, 1,1.5,2])

# %%
a[0],a[1]
# Out:
# (np.int64(1), np.int64(2))

# %%
a=np.array([(1,2,3),(4,5,6)])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# **COMPARING MEMORY SPACE USED;LIST VERSUS NUMPY**

# %%
S = range(1000)
print(sys.getsizeof(5)*len(S))
# Out:
# 28000

# %%
D=np.arange(1000)
print(D.size*D.itemsize)
# Out:
# 8000

# %% [markdown]
# *//AS SEEN ABOVE, NUMPY USES LESS MEMORY THAN A LIST//*

# %% [markdown]
# **COMPARING THE SPEED OF LIST VERSUS NUMPY**

# %%
SIZE=1000
L1=range(SIZE)
L2=range(SIZE)

# %%
A1=np.arange(SIZE)
A2=np.arange(SIZE)

# %%
start=time.time()

# %% [markdown]
# **//calculating sum in a list//**

# %%
result=[(x,y) for x,y in zip(L1,L2)]

# %% [markdown]
# **TIME TAKEN FOR EXECUTION IN A LIST**

# %%
print((time.time()-start)*1000)
# Out:
# 15.777826309204102

# %%
start=time.time()

# %% [markdown]
# **TIME TAKEN FOR EXECUTION IN NUMPY**

# %%
result=A1+A2
print((time.time()-start)*1000)
# Out:
# 9.820699691772461
