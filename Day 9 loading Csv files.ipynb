# %% [markdown]
# <a href="https://colab.research.google.com/github/Obi-chidinma2003/100-days-of-data-repository/blob/main/Day%209%20loading%20Csv%20files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path=("/content/drive/MyDrive/Dataset/dairy_dataset.csv")
df=pd.read_csv(path)
df.head(5)
# Out:
#         Location  Total Land Area (Acres)  Number Of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#         Date  Product Id Product Name                 Brand  \
# 0  44,609.00           5    Ice Cream           Dodla Dairy
# 1      44531           1         Milk                  Amul
# 2      44620           4       Yogurt           Dodla Dairy
# 3      43625           3       Cheese  Britannia Industries
# 4      44179           8   Buttermilk          Mother Dairy
#
#    Quantity (Liters/Kg)  Price Per Unit  ...  Production Date  \
# 0                222.40           85.72  ...            44557
# 1                687.48           42.61  ...            44472
# ...
