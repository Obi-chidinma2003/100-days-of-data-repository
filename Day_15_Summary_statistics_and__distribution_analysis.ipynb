# %% [markdown]
# <a href="https://colab.research.google.com/github/Obi-chidinma2003/100-days-of-data-repository/blob/main/Day_15_Summary_statistics_and__distribution_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING LIBRARIES
# **

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt. style.use('ggplot')

# %%
#pd.set_option('max_columns',50)

# %% [markdown]
# **READING THE DATA**

# %%
path=("/content/drive/MyDrive/Dataset/dairy_dataset.csv")
df=pd.read_csv(path)
df.head(3)
# Out:
#         Location  Total Land Area (Acres)  Number Of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
#
#         Date  Product Id Product Name        Brand  Quantity (Liters/Kg)  \
# 0  44,609.00           5    Ice Cream  Dodla Dairy                222.40
# 1      44531           1         Milk         Amul                687.48
# 2      44620           4       Yogurt  Dodla Dairy                503.48
#
#    Price Per Unit  ...  Production Date  Expiration Date  \
# 0           85.72  ...            44557            44582
# 1           42.61  ...            44472            44494
# 2           36.50  ...            44575            44605
#
#   Quantity Sold (Liters/Kg)  Price Per Unit (Sold)  \
# 0                         7                  82.24
# 1                       558                  39.24
# ...

# %%
df.describe()
# Out:
#        Total Land Area (Acres)  Number Of Cows   Product Id  \
# count              4325.000000     4325.000000  4325.000000
# mean                503.483073       54.963699     5.509595
# std                 285.935061       26.111487     2.842979
# min                  10.170000       10.000000     1.000000
# 25%                 252.950000       32.000000     3.000000
# 50%                 509.170000       55.000000     6.000000
# 75%                 751.250000       77.000000     8.000000
# max                 999.530000      100.000000    10.000000
#
#        Quantity (Liters/Kg)  Price Per Unit   Total Value  Shelf Life (Days)  \
# count           4325.000000     4325.000000   4325.000000        4325.000000
# mean             500.652657       54.785938  27357.845411          29.127630
# std              288.975915       26.002815  21621.051594          30.272114
# min                1.170000       10.030000     42.516500           1.000000
# ...

# %% [markdown]
# **STATISTIC MODULES(MEAN, MEDIAN, MODE AND STANDARD DEVIATION)**

# %%
diary_products=pd.read_csv("/content/drive/MyDrive/Dataset/dairy_dataset.csv")
diary_products=diary_products.rename(columns={'Unnamed: 0':'Location'})
diary_products.index=diary_products.Location
del diary_products["Location"]

mtcars.head()
# Out:
#                Total Land Area (Acres)  Number Of Cows Farm Size       Date  \
# Location
# Telangana                       310.84              96    Medium  44,609.00
# Uttar Pradesh                    19.19              44     Large      44531
# Tamil Nadu                      581.69              24    Medium      44620
# Telangana                       908.00              89     Small      43625
# Maharashtra                     861.95              21    Medium      44179
#
#                Product Id Product Name                 Brand  \
# Location
# Telangana               5    Ice Cream           Dodla Dairy
# Uttar Pradesh           1         Milk                  Amul
# Tamil Nadu              4       Yogurt           Dodla Dairy
# Telangana               3       Cheese  Britannia Industries
# Maharashtra             8   Buttermilk          Mother Dairy
#
#                Quantity (Liters/Kg)  Price Per Unit  Total Value  ...  \
# ...

# %% [markdown]
# **GETTING THE MEAN OF THE EACH COLUMNS**

# %%
diary_products.mean(numeric_only=True)
# Out:
# Total Land Area (Acres)                  503.483073
# Number Of Cows                            54.963699
# Product Id                                 5.509595
# Quantity (Liters/Kg)                     500.652657
# Price Per Unit                            54.785938
# Total Value                            27357.845411
# Shelf Life (Days)                         29.127630
# Production Date                        44150.370405
# Expiration Date                        44179.498035
# Quantity Sold (Liters/Kg)                248.095029
# Price Per Unit (Sold)                     54.779140
# Approx. Total Revenue(Inr)             13580.265401
# Quantity In Stock (Liters/Kg)            252.068671
# Minimum Stock Threshold (Liters/Kg)       55.826143
# Reorder Quantity (Liters/Kg)             109.107820
# dtype: float64

# %%
diary_products.median(numeric_only=True)
# Out:
# Total Land Area (Acres)                  509.1700
# Number Of Cows                            55.0000
# Product Id                                 6.0000
# Quantity (Liters/Kg)                     497.5500
# Price Per Unit                            54.4000
# Total Value                            21869.6529
# Shelf Life (Days)                         22.0000
# Production Date                        44133.0000
# Expiration Date                        44164.0000
# Quantity Sold (Liters/Kg)                189.0000
# Price Per Unit (Sold)                     54.1400
# Approx. Total Revenue(Inr)              8394.5400
# Quantity In Stock (Liters/Kg)            191.0000
# Minimum Stock Threshold (Liters/Kg)       56.4600
# Reorder Quantity (Liters/Kg)             108.3400
# dtype: float64

# %%
diary_products.mode(numeric_only=True)
# Out:
#     Total Land Area (Acres)  Number Of Cows  Product Id  Quantity (Liters/Kg)  \
# 0                    609.62            25.0         6.0                 34.50
# 1                       NaN            89.0         NaN                318.52
# 2                       NaN             NaN         NaN                   NaN
# 3                       NaN             NaN         NaN                   NaN
# 4                       NaN             NaN         NaN                   NaN
# 5                       NaN             NaN         NaN                   NaN
# 6                       NaN             NaN         NaN                   NaN
# 7                       NaN             NaN         NaN                   NaN
# 8                       NaN             NaN         NaN                   NaN
# 9                       NaN             NaN         NaN                   NaN
# 10                      NaN             NaN         NaN                   NaN
# ...

# %%
diary_products.std(numeric_only=True)
# Out:
# Total Land Area (Acres)                  285.935061
# Number Of Cows                            26.111487
# Product Id                                 2.842979
# Quantity (Liters/Kg)                     288.975915
# Price Per Unit                            26.002815
# Total Value                            21621.051594
# Shelf Life (Days)                         30.272114
# Production Date                          420.265444
# Expiration Date                          421.258646
# Quantity Sold (Liters/Kg)                217.024182
# Price Per Unit (Sold)                     26.192790
# Approx. Total Revenue(Inr)             14617.009122
# Quantity In Stock (Liters/Kg)            223.620870
# Minimum Stock Threshold (Liters/Kg)       26.301450
# Reorder Quantity (Liters/Kg)              51.501035
# dtype: float64

# %%
diary_products.skew(numeric_only=True)
# Out:
# Total Land Area (Acres)               -0.020572
# Number Of Cows                         0.019617
# Product Id                            -0.024827
# Quantity (Liters/Kg)                  -0.014906
# Price Per Unit                         0.009322
# Total Value                            0.873985
# Shelf Life (Days)                      2.082496
# Production Date                        0.058688
# Expiration Date                        0.060301
# Quantity Sold (Liters/Kg)              0.981983
# Price Per Unit (Sold)                  0.014239
# Approx. Total Revenue(Inr)             1.691646
# Quantity In Stock (Liters/Kg)          0.962301
# Minimum Stock Threshold (Liters/Kg)   -0.041864
# Reorder Quantity (Liters/Kg)           0.013757
# dtype: float64

# %%
diary_products.kurtosis(numeric_only=True)
sns.histplot(diary_products)
sns
# Out:
# <Axes: ylabel='Count'>
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.value_counts()
# Out:
# Location     Total Land Area (Acres)  Number Of Cows  Farm Size  Date   Product Id  Product Name  Brand         Quantity (Liters/Kg)  Price Per Unit  Total Value  Shelf Life (Days)  Storage Condition  Production Date  Expiration Date  Quantity Sold (Liters/Kg)  Price Per Unit (Sold)  Approx. Total Revenue(Inr)  Customer Location  Sales Channel  Quantity In Stock (Liters/Kg)  Minimum Stock Threshold (Liters/Kg)  Reorder Quantity (Liters/Kg)
# West Bengal  990.93                   39              Large      44382  2           Butter        Amul          362.45                80.31           29108.3595   27                 Refrigerated       44363            44390            313                        80.06                  25058.78                    Madhya Pradesh     Wholesale      49                             10.42                                101.82                          1
# ...
